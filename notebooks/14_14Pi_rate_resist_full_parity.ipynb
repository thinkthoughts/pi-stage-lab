# %% [markdown]
# # 14 — 14Pi Rate Resist
#
# **Repo:** `pi-stage-lab`
# **Notebook:** `14_14Pi_rate_resist.ipynb`
# **Stage:** `14Pi`
# **Triplet position:** `resist`
# **Track:** `rate`
#
# 14Pi completes the rate triplet: a valid rate preserves meaning under constraint pressure.
#
# This notebook is intentionally generic. Domain translations belong in `docs/` bridge files and later notebooks.

# %% [markdown]
# ## 14Pi rule
#
# > A valid rate preserves meaning under constraint pressure.
#
# - **VC / GOS:** interval, baseline, and comparison context remain preserved.
# - **IA / ZOS:** rate context collapses and is replaced by interpretation.
# - **14Pi resist:** preserve rate meaning under constraint.

# %% [markdown]
# ## 14Pi template contract
#
# Every Pi-stage notebook should preserve the same build pattern:
#
# ```txt
# docs/{stage}_glossary.md
# docs/{stage}_notes.md
# docs/{stage}_readme_snippet.md
# results/{stage}_metadata.json
# results/{stage}_claims.json
# results/{stage}_claims.csv
# results/{stage}_manifest.json
# figures/{stage}_*.png
# math/{stage}_*.tex
# ```
#
# The notebook is the source of truth. `docs/`, `results/`, `figures/`, and `math/` are generated outputs.

# %% [markdown]
# ## Translation boundary
#
# **14Pi is still grammar, not application.**
#
# Do not hard-code this notebook into CO₂, O₂, photons, climate, chemistry, or any other domain.
#
# Translations belong in bridge docs, later Pi-stage notebooks, or 17pi.org pages.

# %%
from pathlib import Path
import json
import csv
import zipfile
import matplotlib.pyplot as plt

ROOT = Path(".")
DOCS = ROOT / "docs"
RESULTS = ROOT / "results"
FIGURES = ROOT / "figures"
MATH = ROOT / "math"

for folder in [DOCS, RESULTS, FIGURES, MATH]:
    folder.mkdir(exist_ok=True)

print("Initialized folders:", DOCS, RESULTS, FIGURES, MATH)

# %% [markdown]
# ## Stage metadata
#
# This metadata gives every notebook a consistent schema.

# %%
stage_prefix = "14_14Pi"

stage = {
    "notebook": "14_14Pi_rate_resist",
    "pi_stage": "14Pi",
    "triplet_position": "resist",
    "track": "rate",
    "core_rule": "Preserve rate meaning under constraint pressure.",
    "template_role": "Generic Pi-stage notebook completing the rate triplet.",
    "translation_boundary": "Do not lock 14Pi to CO2, O2, photons, climate, chemistry, or any domain.",
    "previous_stage": "13_13Pi_rate_extend",
    "next_stage": "15_15Pi_translation_expand",
    "cgcs_target": 0.96,
    "template_version": "0.2",
    "outputs": ["docs", "results", "figures", "math"],
    "triplet_map": {
        "12Pi": "expand rate",
        "13Pi": "extend rate",
        "14Pi": "resist rate"
    },
    "rate_stability_terms": {
        "delta_n": "preserved interval",
        "B": "preserved baseline",
        "C": "preserved comparison",
        "delta_rc": "bounded comparable-rate variation"
    },
}

stage

# %% [markdown]
# ## TPL rate resistance gate
#
# The notebook does not translate this yet into CO₂, O₂, photons, climate, chemistry, or any other domain. It only establishes the generic rate-resistance gate.

# %%
triplet_n = "(Spiral N × 24) − 25"
constraint = "≠ ±9424Pi ≠ 9423Pi"

identity_statement = f"Triplet N = {triplet_n} {constraint}"
print(identity_statement)
print("14Pi resist: comparable rate preserves interval, baseline, and meaning under constraint.")

# %% [markdown]
# ## Generic rate stability components
#
# At 14Pi, rate is not only measured and comparable; rate meaning is preserved under constraint pressure.
#
# Generic rate stability components:
#
# - preserved interval
# - preserved baseline
# - preserved comparison context
# - bounded comparable-rate variation
# - stable rate meaning
# - rate interpretation boundary

# %%
rate_stability_components = [
    "preserved interval",
    "preserved baseline",
    "preserved comparison context",
    "bounded comparable-rate variation",
    "stable rate meaning",
    "rate interpretation boundary",
]

print("Preserving rate meaning under constraint:")
for item in rate_stability_components:
    print("-", item)

# %% [markdown]
# ## Generic glossary
#
# | TPL / CGCS term | Generic meaning | Later translations |
# |---|---|---|
# | rate | measured change per interval | concentration change, flux rate, warming rate |
# | resist | preserve rate meaning under constraint | rate stability, context preservation |
# | interval | counted step or measurement span | Δn, sample step, observation interval |
# | baseline | reference quantity or condition | reference concentration, reference flux |
# | comparison | relation between rates or rate contexts | relative rate, normalized rate |
# | stable rate | comparable rate preserved under constraint | validated rate comparison |
# | context collapse | rate claim losing interval or baseline | misleading comparison |
# | valid construction / VC | rate context preserved under constraint | physics/chemistry model |
# | invalid assignment / IA | rate remains valid after context is lost | slogan collapse |
# | CGCS | constraint-gated comprehension score | claim-quality score |

# %%
glossary_md = """# 14 — 14Pi Glossary: Rate Resist

## Core rule

A valid rate preserves meaning under constraint pressure.

## Rate triplet

- 12Pi: expand stable system behavior into measurable rates of change
- 13Pi: extend rate across intervals, baselines, and comparisons
- 14Pi: resist rate collapse by preserving rate meaning under constraint

## Template contract

Every Pi-stage notebook should keep the same output pattern:

- docs/{stage}_glossary.md
- docs/{stage}_notes.md
- docs/{stage}_readme_snippet.md
- results/{stage}_metadata.json
- results/{stage}_claims.json
- results/{stage}_claims.csv
- results/{stage}_manifest.json
- figures/{stage}_*.png
- math/{stage}_*.tex

## Generic terms

| TPL / CGCS term | Generic meaning | Later translations |
|---|---|---|
| rate | measured change per interval | concentration change, flux rate, warming rate |
| resist | preserve rate meaning under constraint | rate stability, context preservation |
| interval | counted step or measurement span | Δn, sample step, observation interval |
| baseline | reference quantity or condition | reference concentration, reference flux |
| comparison | relation between rates or rate contexts | relative rate, normalized rate |
| stable rate | comparable rate preserved under constraint | validated rate comparison |
| context collapse | rate claim losing interval or baseline | misleading comparison |
| valid construction / VC | rate context preserved under constraint | physics/chemistry model |
| invalid assignment / IA | rate remains valid after context is lost | slogan collapse |
| CGCS | constraint-gated comprehension score | claim-quality score |

## Translation boundary

14Pi is grammar, not application. Do not lock 14Pi to one domain.

Translate into photons, CO2, O2, climate, chemistry, or public claims later in bridge docs and later notebooks.
"""

(DOCS / "14_14Pi_glossary.md").write_text(glossary_md)
print("Wrote", DOCS / "14_14Pi_glossary.md")

# %% [markdown]
# ## CGCS rate scoring
#
# At 14Pi, the score evaluates whether rate meaning is preserved under constraint.
#
# - **0.96:** interval, baseline, and comparison context are preserved.
# - **0.64:** partly grounded but under-specified.
# - **0.33:** rate context collapses.
# - **0.00:** incoherent or unsupported assignment.

# %%
claims = [
    {
        "claim": "A valid rate preserves meaning under constraint pressure.",
        "cgcs": 0.96,
        "classification": "VC/GOS",
        "reason": "Maintains interval, baseline, and comparison context under constraint.",
    },
    {
        "claim": "Constraint pressure makes rate comparisons meaningless by definition.",
        "cgcs": 0.33,
        "classification": "IA/ZOS",
        "reason": "Confuses constraint with rate collapse.",
    },
    {
        "claim": "Rate stability requires preserved interval, baseline, and bounded variation.",
        "cgcs": 0.96,
        "classification": "VC/GOS",
        "reason": "Connects rate extension to constraint-resistance.",
    },
    {
        "claim": "A rate remains valid even when interval and baseline are lost.",
        "cgcs": 0.33,
        "classification": "IA/ZOS",
        "reason": "Removes measurable context from rate validity.",
    },
]

claims

# %%
(RESULTS / "14_14Pi_metadata.json").write_text(json.dumps(stage, indent=2))
(RESULTS / "14_14Pi_claims.json").write_text(json.dumps(claims, indent=2))

with open(RESULTS / "14_14Pi_claims.csv", "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=["claim", "cgcs", "classification", "reason"])
    writer.writeheader()
    writer.writerows(claims)

print("Wrote results JSON/CSV")

# %% [markdown]
# ## Figure 1 — Rate resistance
#
# This figure is intentionally domain-agnostic.
#
# 14Pi completes the rate triplet by preserving rate meaning under constraint.

# %%
fig, ax = plt.subplots(figsize=(9.4, 3.6))

x = [0, 1, 2]
labels = ["comparable\nrate", "constraint\npressure", "rate meaning\npreserved"]

ax.scatter(x, [0, 0, 0], s=1000)

for xi, label in zip(x, labels):
    ax.text(xi, -0.42, label, ha="center", va="top", fontsize=12)

ax.annotate("", xy=(0.78, 0), xytext=(0.22, 0), arrowprops=dict(arrowstyle="->", lw=2.5))
ax.annotate("", xy=(1.78, 0), xytext=(1.22, 0), arrowprops=dict(arrowstyle="->", lw=2.5))

ax.text(0, 0.32, "13Pi comparable rate", ha="center", va="bottom", fontsize=10)
ax.text(1, 0.32, "14Pi resist", ha="center", va="bottom", fontsize=10)
ax.text(2, 0.32, "interval + baseline preserved", ha="center", va="bottom", fontsize=10)

ax.set_title("14Pi rate resist: rate meaning preserved under constraint")
ax.set_xlim(-0.45, 2.45)
ax.set_ylim(-0.85, 0.65)
ax.axis("off")

fig_path = FIGURES / "14_14Pi_rate_resist.png"
plt.savefig(fig_path, dpi=200, bbox_inches="tight")
plt.show()

print("Saved", fig_path)

# %% [markdown]
# ## Figure 2 — VC/GOS vs IA/ZOS
#
# This figure is the reusable rate-resistance template: valid construction preserves context; invalid assignment collapses context.

# %%
fig, ax = plt.subplots(figsize=(8.5, 4.8))

ax.plot([0.5, 0.5], [0.12, 0.88], linewidth=1.8)

ax.text(0.25, 0.78, "IA / ZOS", ha="center", va="center", fontsize=16, weight="bold")
ax.text(0.25, 0.52, "context\ncollapse", ha="center", va="center", fontsize=12)
ax.text(0.25, 0.27, "baseline lost", ha="center", va="center", fontsize=12)

ax.text(0.75, 0.78, "VC / GOS", ha="center", va="center", fontsize=16, weight="bold")
ax.text(0.75, 0.52, "stable\nrate", ha="center", va="center", fontsize=12)
ax.text(0.75, 0.27, "context preserved", ha="center", va="center", fontsize=12)

ax.set_title("14Pi CGCS gate: stable rate vs context collapse")
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis("off")

fig_path = FIGURES / "14_14Pi_vc_gos_vs_ia_zos.png"
plt.savefig(fig_path, dpi=200, bbox_inches="tight")
plt.show()

print("Saved", fig_path)

# %% [markdown]
# ## Math output
#
# This TeX output gives each Pi stage a formal layer for papers, 17pi.org, or later combined manuscripts.
#
# 14Pi math stays generic: rate meaning preserved under constraint.

# %%
math_tex = r"""\section*{14Pi Rate Resist}

\textbf{Core rule:}
\[
\mathrm{Rate}_{14\Pi}
=
\mathrm{Stable}\left(\mathrm{Rate}_{13\Pi}(\Delta n,B,C)\right)
\]

\textbf{Context preservation:}
\[
\{\Delta n, B, C\}_{14\Pi}
=
\{\Delta n, B, C\}_{13\Pi}
\quad \text{under constraint}
\]

\textbf{Bounded rate variation:}
\[
\Delta r_c \leq \epsilon
\]

\textbf{CGCS gate:}
\[
\mathrm{Rate} \rightarrow
\begin{cases}
\mathrm{stable\ rate} & \text{VC/GOS} \\
\mathrm{context\ collapse} & \text{IA/ZOS}
\end{cases}
\]

\textbf{Rate triplet:}
\[
12\Pi:\mathrm{expand}
\quad\rightarrow\quad
13\Pi:\mathrm{extend}
\quad\rightarrow\quad
14\Pi:\mathrm{resist}
\]
"""

(MATH / "14_14Pi_rate.tex").write_text(math_tex)
print("Wrote", MATH / "14_14Pi_rate.tex")

# %% [markdown]
# ## Bridge note stub
#
# This is the generic bridge note. Later docs can translate 14Pi into carbon cycle, photonics, oxygen, climate, chemistry, or public-language analysis.

# %%
notes_md = """# 14 — 14Pi Rate Resist Notes

## Core statement

14Pi preserves rate meaning under constraint pressure.

## Rate triplet

- 12Pi: expand stable system behavior into measurable rates of change
- 13Pi: extend rate across intervals, baselines, and comparisons
- 14Pi: resist rate collapse by preserving rate meaning under constraint

## Rate resistance

14Pi completes the rate triplet.

A valid rate:
- preserves interval
- preserves baseline
- keeps variation bounded
- remains comparable under constraint

An invalid rate:
- loses interval
- hides baseline
- treats context collapse as comparison
- replaces rate stability with interpretation

## Figures

### Rate resistance
![14Pi rate resist](../figures/14_14Pi_rate_resist.png)

### CGCS gate (VC/GOS vs IA/ZOS)
![14Pi CGCS gate](../figures/14_14Pi_vc_gos_vs_ia_zos.png)

## Results

### Metadata
- [14_14Pi_metadata.json](../results/14_14Pi_metadata.json)

### Claim scoring
- [14_14Pi_claims.json](../results/14_14Pi_claims.json)
- [14_14Pi_claims.csv](../results/14_14Pi_claims.csv)

### Manifest
- [14_14Pi_manifest.json](../results/14_14Pi_manifest.json)

## Template use

This notebook should be cloned for later Pi stages. Keep the same output pattern:

- docs/*.md for human-readable bridge notes
- results/*.json and results/*.csv for machine-readable claim scoring
- results/*_manifest.json for output inventory
- figures/*.png for site, paper, and seminar visuals
- math/*.tex for formal paper-ready equations

## Translation boundary

14Pi is grammar, not application.

Photons, CO2, O2, carbon cycle, climate claims, and public-language examples should be added in bridge docs or later notebooks, not hard-coded into 14Pi.

## High-CGCS 14Pi framing

A valid rate preserves meaning under constraint pressure.

## Low-CGCS 14Pi collapse

A rate remains valid even when interval and baseline are lost.
"""

(DOCS / "14_14Pi_notes.md").write_text(notes_md)
print("Wrote", DOCS / "14_14Pi_notes.md")

# %% [markdown]
# ## README snippet
#
# This generated snippet can be copied into `README.md` or adapted for a 17pi.org entry page.

# %%
readme_snippet_md = """## 14 — 14Pi Rate Resist

14Pi preserves rate meaning under constraint pressure.

**Core rule:** a valid rate preserves meaning under constraint pressure.

**Rate triplet:** 12Pi expand → 13Pi extend → 14Pi resist.

**Template role:** this notebook completes the rate triplet and preserves the Pi-stage output pattern:

- `docs/` for bridge notes and glossary
- `results/` for CGCS claim scoring and metadata
- `figures/` for reusable visuals
- `math/` for TeX equations

**Rate stability:** preserved interval + preserved baseline + bounded comparable-rate variation.

**Translation boundary:** 14Pi is grammar, not application. Translations into photons, CO2, O2, carbon cycle, climate, chemistry, or public-language claims belong in bridge docs and later notebooks.
"""

(DOCS / "14_14Pi_readme_snippet.md").write_text(readme_snippet_md)
print("Wrote", DOCS / "14_14Pi_readme_snippet.md")

# %% [markdown]
# ## Output manifest
#
# The manifest makes each Pi-stage notebook auditable: it records which files this notebook generated.

# %%
manifest = {
    "notebook": "notebooks/14_14Pi_rate_resist.ipynb",
    "docs": [
        "docs/14_14Pi_glossary.md",
        "docs/14_14Pi_notes.md",
        "docs/14_14Pi_readme_snippet.md",
    ],
    "results": [
        "results/14_14Pi_metadata.json",
        "results/14_14Pi_claims.json",
        "results/14_14Pi_claims.csv",
        "results/14_14Pi_manifest.json",
    ],
    "figures": [
        "figures/14_14Pi_rate_resist.png",
        "figures/14_14Pi_vc_gos_vs_ia_zos.png",
    ],
    "math": [
        "math/14_14Pi_rate.tex",
    ],
}

(RESULTS / "14_14Pi_manifest.json").write_text(json.dumps(manifest, indent=2))
manifest

# %% [markdown]
# ## Validate outputs
#
# This cell checks that the expected generated files exist before export.

# %%
expected_paths = []
for group in ["docs", "results", "figures", "math"]:
    expected_paths.extend(manifest[group])

missing = [path for path in expected_paths if not Path(path).exists()]

if missing:
    raise FileNotFoundError("Missing expected outputs: " + ", ".join(missing))

print("All expected outputs exist.")

# %% [markdown]
# ## Optional export
#
# Run this final cell to zip generated docs, results, figures, and math outputs for download or repo upload.

# %%
EXPORT_NAME = "14_14Pi_rate_resist_export.zip"

with zipfile.ZipFile(EXPORT_NAME, "w", zipfile.ZIP_DEFLATED) as z:
    for folder in [DOCS, RESULTS, FIGURES, MATH]:
        for path in folder.rglob("*"):
            if path.is_file():
                z.write(path, path.as_posix())

print(f"Export ready: {EXPORT_NAME}")
print("Tip: uncomment Colab lines below to download.")

# --- Optional Colab download ---
# Uncomment the lines below when running in Colab
#
# from google.colab import files
# files.download(EXPORT_NAME)
