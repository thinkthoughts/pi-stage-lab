# %% [markdown]
# # 00 — 0Pi Identity Expand
#
# **Repo:** `pi-stage-lab`
# **Notebook:** `00_0Pi_identity_expand.ipynb`
# **Stage:** `0Pi`
# **Triplet position:** `expand`
# **Track:** `identity`
#
# 0Pi starts with identity expansion: define a measurable structure before translating it into domain-specific examples such as photons, CO₂, O₂, climate, chemistry, or public-language claims.
#
# This notebook is intentionally generic. Domain translations belong in `docs/` bridge files and later notebooks.

# %% [markdown]
# ## 0Pi rule
#
# > A valid identity is a measurable structure before it is a slogan, metaphor, public claim, or interpretation.
#
# In TPL / CGCS terms:
#
# - **VC / GOS:** valid construction; measurement-grounded identity.
# - **IA / ZOS:** invalid assignment; interpretation replacing measurement.
# - **0Pi expand:** establish identity without collapsing it into a single story.

# %% [markdown]
# ## 0Pi template contract
#
# Every Pi-stage notebook should preserve the same build pattern:
#
# ```txt
# docs/{stage}_glossary.md
# docs/{stage}_notes.md
# docs/{stage}_readme_snippet.md
# results/{stage}_metadata.json
# results/{stage}_claims.json
# results/{stage}_claims.csv
# results/{stage}_manifest.json
# figures/{stage}_*.png
# math/{stage}_*.tex
# ```
#
# The notebook is the source of truth. `docs/`, `results/`, `figures/`, and `math/` are generated outputs.

# %% [markdown]
# ## Translation boundary
#
# **0Pi is grammar, not application.**
#
# Do not hard-code this notebook into CO₂, O₂, photons, climate, chemistry, or any other domain.
#
# Those translations belong in:
#
# - bridge docs, such as `docs/carbon_cycle.md` or `docs/photonics.md`
# - later Pi-stage notebooks, such as `17_17Pi_co2_connector_resist.ipynb`
# - site pages, such as `17pi.org/carbon-dioxide`

# %%
from pathlib import Path
import json
import csv
import zipfile
import matplotlib.pyplot as plt

# Output folders: same pattern should be reused in later Pi-stage notebooks.
ROOT = Path(".")
DOCS = ROOT / "docs"
RESULTS = ROOT / "results"
FIGURES = ROOT / "figures"
MATH = ROOT / "math"

for folder in [DOCS, RESULTS, FIGURES, MATH]:
    folder.mkdir(exist_ok=True)

print("Initialized folders:", DOCS, RESULTS, FIGURES, MATH)

# %% [markdown]
# ## Stage metadata
#
# This metadata gives every notebook a consistent schema. Later stages should update only these fields, not the whole pattern.

# %%
stage_prefix = "00_0Pi"

stage = {
    "notebook": "00_0Pi_identity_expand",
    "pi_stage": "0Pi",
    "triplet_position": "expand",
    "track": "identity",
    "core_rule": "Define measurable identity before interpretation.",
    "template_role": "Generic Pi-stage notebook schema seed.",
    "translation_boundary": "Do not lock 0Pi to CO2, O2, photons, climate, chemistry, or any domain.",
    "next_stage": "01_1Pi_identity_extend",
    "cgcs_target": 0.96,
    "template_version": "0.2",
    "outputs": ["docs", "results", "figures", "math"],
}

stage

# %% [markdown]
# ## TPL identity constraint
#
# The notebook does not translate this yet into photons, CO₂, O₂, or any other domain. It only establishes the generic identity gate.

# %%
triplet_n = "(Spiral N × 24) − 25"
constraint = "≠ ±9424Pi ≠ 9423Pi"

identity_statement = f"Triplet N = {triplet_n} {constraint}"
print(identity_statement)
print("0Pi expand: establish valid identity before domain translation.")

# %% [markdown]
# ## Generic glossary
#
# | TPL / CGCS term | Generic meaning | Later translations |
# |---|---|---|
# | identity | measurable structure | photon, molecule, field, state, cycle variable |
# | expand | define without collapse | initial observable definition |
# | valid construction / VC | measurement-grounded structure | physics/chemistry model |
# | general-origin story / GOS | identity preserved through constraints | system-aware framing |
# | invalid assignment / IA | interpretation without measurement | slogan collapse |
# | zero-origin story / ZOS | claim pretending an unsupported origin | public-language shortcut |
# | constraint signal | measurable variable connecting states | angle, flux, concentration, energy, rate |
# | CGCS | constraint-gated comprehension score | claim-quality score |

# %%
glossary_md = """# 00 — 0Pi Glossary: Identity Expand

## Core rule

A valid identity is a measurable structure before it is a slogan, metaphor, public claim, or interpretation.

## Template contract

Every Pi-stage notebook should keep the same output pattern:

- docs/{stage}_glossary.md
- docs/{stage}_notes.md
- docs/{stage}_readme_snippet.md
- results/{stage}_metadata.json
- results/{stage}_claims.json
- results/{stage}_claims.csv
- results/{stage}_manifest.json
- figures/{stage}_*.png
- math/{stage}_*.tex

## Generic terms

| TPL / CGCS term | Generic meaning | Later translations |
|---|---|---|
| identity | measurable structure | photon, molecule, field, state, cycle variable |
| expand | define without collapse | initial observable definition |
| valid construction / VC | measurement-grounded structure | physics/chemistry model |
| general-origin story / GOS | identity preserved through constraints | system-aware framing |
| invalid assignment / IA | interpretation without measurement | slogan collapse |
| zero-origin story / ZOS | claim pretending an unsupported origin | public-language shortcut |
| constraint signal | measurable variable connecting states | angle, flux, concentration, energy, rate |
| CGCS | constraint-gated comprehension score | claim-quality score |

## Translation boundary

0Pi is grammar, not application. Do not lock 0Pi to one domain.

Translate into photons, CO2, O2, climate, chemistry, or public claims later in bridge docs and later notebooks.
"""

(DOCS / "00_0Pi_glossary.md").write_text(glossary_md)
print("Wrote", DOCS / "00_0Pi_glossary.md")

# %% [markdown]
# ## CGCS identity scoring
#
# At 0Pi, the score asks whether a claim preserves measurable identity before interpretation.
#
# - **0.96:** preserves measurable identity and avoids collapse.
# - **0.64:** partly grounded but under-specified.
# - **0.33:** collapses identity into an interpretation.
# - **0.00:** incoherent or unsupported assignment.

# %%
claims = [
    {
        "claim": "A system identity should be defined by measurable structure before interpretation.",
        "cgcs": 0.96,
        "classification": "VC/GOS",
        "reason": "Preserves identity before domain translation.",
    },
    {
        "claim": "A thing means whatever public story is attached to it first.",
        "cgcs": 0.33,
        "classification": "IA/ZOS",
        "reason": "Collapses identity into interpretation.",
    },
    {
        "claim": "A measurable variable can become a constraint signal when it links system states.",
        "cgcs": 0.96,
        "classification": "VC/GOS",
        "reason": "Defines identity by function inside constraints.",
    },
    {
        "claim": "A single slogan is enough to define a physical system.",
        "cgcs": 0.33,
        "classification": "IA/ZOS",
        "reason": "Replaces measurement with public-language collapse.",
    },
]

claims

# %%
# Save metadata and claim scores in reusable machine-readable formats.
(RESULTS / "00_0Pi_metadata.json").write_text(json.dumps(stage, indent=2))
(RESULTS / "00_0Pi_claims.json").write_text(json.dumps(claims, indent=2))

with open(RESULTS / "00_0Pi_claims.csv", "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=["claim", "cgcs", "classification", "reason"])
    writer.writeheader()
    writer.writerows(claims)

print("Wrote results JSON/CSV")

# %% [markdown]
# ## Figure 1 — Identity before interpretation
#
# This figure is intentionally domain-agnostic. Later bridge docs can translate this into photons, molecules, carbon cycle variables, or other systems.
#
# The labels sit outside the nodes so the figure stays readable in notebook, website, and slide contexts.

# %%
fig, ax = plt.subplots(figsize=(9, 3.4))

x = [0, 1, 2]
labels = ["measurable\nstructure", "interaction", "persistence\nacross constraint"]

ax.scatter(x, [0, 0, 0], s=900)

for xi, label in zip(x, labels):
    ax.text(xi, -0.42, label, ha="center", va="top", fontsize=12)

ax.annotate("", xy=(0.78, 0), xytext=(0.22, 0), arrowprops=dict(arrowstyle="->", lw=2.5))
ax.annotate("", xy=(1.78, 0), xytext=(1.22, 0), arrowprops=dict(arrowstyle="->", lw=2.5))

ax.text(0, 0.32, "define", ha="center", va="bottom", fontsize=10)
ax.text(1, 0.32, "test", ha="center", va="bottom", fontsize=10)
ax.text(2, 0.32, "preserve", ha="center", va="bottom", fontsize=10)

ax.set_title("0Pi identity expand: define before translation")
ax.set_xlim(-0.45, 2.45)
ax.set_ylim(-0.85, 0.65)
ax.axis("off")

fig_path = FIGURES / "00_0Pi_identity_expand.png"
plt.savefig(fig_path, dpi=200, bbox_inches="tight")
plt.show()

print("Saved", fig_path)

# %% [markdown]
# ## Figure 2 — VC/GOS vs IA/ZOS
#
# This figure is the reusable claim-quality template: valid construction preserves identity; invalid assignment collapses identity into interpretation.

# %%
fig, ax = plt.subplots(figsize=(8.5, 4.8))

# panel divider
ax.plot([0.5, 0.5], [0.12, 0.88], linewidth=1.8)

# left panel
ax.text(0.25, 0.78, "IA / ZOS", ha="center", va="center", fontsize=16, weight="bold")
ax.text(0.25, 0.52, "interpretation\nwithout measurement", ha="center", va="center", fontsize=12)
ax.text(0.25, 0.27, "identity collapse", ha="center", va="center", fontsize=12)

# right panel
ax.text(0.75, 0.78, "VC / GOS", ha="center", va="center", fontsize=16, weight="bold")
ax.text(0.75, 0.52, "measurable\nstructure first", ha="center", va="center", fontsize=12)
ax.text(0.75, 0.27, "identity preserved", ha="center", va="center", fontsize=12)

ax.set_title("0Pi CGCS gate: identity collapse vs identity preservation")
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis("off")

fig_path = FIGURES / "00_0Pi_vc_gos_vs_ia_zos.png"
plt.savefig(fig_path, dpi=200, bbox_inches="tight")
plt.show()

print("Saved", fig_path)

# %% [markdown]
# ## Math output
#
# This TeX output gives each Pi stage a formal layer for papers, 17pi.org, or later combined manuscripts.
#
# 0Pi math stays generic: identity, constraint, and CGCS gate only.

# %%
math_tex = r"""\section*{0Pi Identity Expand}

\textbf{Core rule:}
\[
\mathrm{Identity} = \mathrm{measurable\ structure} \neq \mathrm{interpretation}
\]

\textbf{Constraint form:}
\[
\mathrm{Triplet\ N} = (N \cdot 24) - 25 \neq \pm 9424\pi \neq 9423\pi
\]

\textbf{CGCS gate:}
\[
\mathrm{IA/ZOS} \rightarrow \mathrm{identity\ collapse}
\]
\[
\mathrm{VC/GOS} \rightarrow \mathrm{identity\ preserved}
\]

\textbf{0Pi translation boundary:}
\[
0\Pi = \mathrm{grammar} \neq \mathrm{application}
\]
"""

(MATH / "00_0Pi_identity.tex").write_text(math_tex)
print("Wrote", MATH / "00_0Pi_identity.tex")

# %% [markdown]
# ## Bridge note stub
#
# This is the generic bridge note. Later docs can translate 0Pi into carbon cycle, photonics, oxygen, climate, chemistry, or public-language analysis.

# %%
notes_md = """# 00 — 0Pi Identity Expand Notes

## Core statement

0Pi establishes identity before interpretation.

## Template use

This notebook should be cloned for later Pi stages. Keep the same output pattern:

- docs/*.md for human-readable bridge notes
- results/*.json and results/*.csv for machine-readable claim scoring
- results/*_manifest.json for output inventory
- figures/*.png for site, paper, and seminar visuals
- math/*.tex for formal paper-ready equations

## Translation boundary

0Pi is grammar, not application.

Photons, CO2, O2, carbon cycle, climate claims, and public-language examples should be added in bridge docs or later notebooks, not hard-coded into 0Pi.

## High-CGCS 0Pi framing

A system identity should be defined by measurable structure before interpretation.

## Low-CGCS 0Pi collapse

A single slogan is enough to define a physical system.
"""

(DOCS / "00_0Pi_notes.md").write_text(notes_md)
print("Wrote", DOCS / "00_0Pi_notes.md")

# %% [markdown]
# ## README snippet
#
# This generated snippet can be copied into `README.md` or adapted for a 17pi.org entry page.

# %%
readme_snippet_md = """## 00 — 0Pi Identity Expand

0Pi establishes identity before interpretation.

**Core rule:** a valid identity is a measurable structure before it is a slogan, metaphor, public claim, or interpretation.

**Template role:** this notebook seeds the Pi-stage output pattern:

- `docs/` for bridge notes and glossary
- `results/` for CGCS claim scoring and metadata
- `figures/` for reusable visuals
- `math/` for TeX equations

**Translation boundary:** 0Pi is grammar, not application. Translations into photons, CO2, O2, carbon cycle, climate, chemistry, or public-language claims belong in bridge docs and later notebooks.
"""

(DOCS / "00_0Pi_readme_snippet.md").write_text(readme_snippet_md)
print("Wrote", DOCS / "00_0Pi_readme_snippet.md")

# %% [markdown]
# ## Output manifest
#
# The manifest makes each Pi-stage notebook auditable: it records which files this notebook generated.

# %%
manifest = {
    "notebook": "notebooks/00_0Pi_identity_expand.ipynb",
    "docs": [
        "docs/00_0Pi_glossary.md",
        "docs/00_0Pi_notes.md",
        "docs/00_0Pi_readme_snippet.md",
    ],
    "results": [
        "results/00_0Pi_metadata.json",
        "results/00_0Pi_claims.json",
        "results/00_0Pi_claims.csv",
        "results/00_0Pi_manifest.json",
    ],
    "figures": [
        "figures/00_0Pi_identity_expand.png",
        "figures/00_0Pi_vc_gos_vs_ia_zos.png",
    ],
    "math": [
        "math/00_0Pi_identity.tex",
    ],
}

(RESULTS / "00_0Pi_manifest.json").write_text(json.dumps(manifest, indent=2))
manifest

# %% [markdown]
# ## Validate outputs
#
# This cell checks that the expected generated files exist before export.

# %%
expected_paths = []
for group in ["docs", "results", "figures", "math"]:
    expected_paths.extend(manifest[group])

missing = [path for path in expected_paths if not Path(path).exists()]

if missing:
    raise FileNotFoundError("Missing expected outputs: " + ", ".join(missing))

print("All expected outputs exist.")

# %% [markdown]
# ## Optional export
#
# Run this final cell to zip generated docs, results, figures, and math outputs for download or repo upload.

# %%
EXPORT_NAME = "00_0Pi_identity_expand_export.zip"

with zipfile.ZipFile(EXPORT_NAME, "w", zipfile.ZIP_DEFLATED) as z:
    for folder in [DOCS, RESULTS, FIGURES, MATH]:
        for path in folder.rglob("*"):
            if path.is_file():
                z.write(path, path.as_posix())

print(f"Export ready: {EXPORT_NAME}")

# In Google Colab, uncomment the next two lines:
# from google.colab import files
# files.download(EXPORT_NAME)
