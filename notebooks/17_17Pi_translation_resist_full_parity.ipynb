# %% [markdown]
# # 17 — 17Pi Translation Resist
#
# **Repo:** `pi-stage-lab`
# **Notebook:** `17_17Pi_translation_resist.ipynb`
# **Stage:** `17Pi`
# **Triplet position:** `resist`
# **Track:** `translation`
#
# 17Pi completes the translation triplet: a valid public translation preserves measured meaning under interpretation pressure.
#
# This notebook is intentionally generic. Domain translations belong in `docs/` bridge files and later notebooks.

# %% [markdown]
# ## 17Pi rule
#
# > A valid public translation preserves measured meaning under interpretation pressure.
#
# - **VC / GOS:** mapped quantities, context, and representation boundaries remain recoverable.
# - **IA / ZOS:** persuasive framing replaces measurable structure.
# - **17Pi resist:** preserve measured meaning through public-language pressure.

# %% [markdown]
# ## 17Pi template contract
#
# Every Pi-stage notebook should preserve the same build pattern:
#
# ```txt
# docs/{stage}_glossary.md
# docs/{stage}_notes.md
# docs/{stage}_readme_snippet.md
# results/{stage}_metadata.json
# results/{stage}_claims.json
# results/{stage}_claims.csv
# results/{stage}_manifest.json
# figures/{stage}_*.png
# math/{stage}_*.tex
# ```
#
# The notebook is the source of truth. `docs/`, `results/`, `figures/`, and `math/` are generated outputs.

# %% [markdown]
# ## Translation boundary
#
# **17Pi is public-translation grammar, not domain application.**
#
# Do not hard-code this notebook into CO₂, O₂, photons, climate, chemistry, or any other domain.
#
# Translations belong in bridge docs, later Pi-stage notebooks, or 17pi.org pages.

# %%
from pathlib import Path
import json
import csv
import zipfile
import matplotlib.pyplot as plt

ROOT = Path(".")
DOCS = ROOT / "docs"
RESULTS = ROOT / "results"
FIGURES = ROOT / "figures"
MATH = ROOT / "math"

for folder in [DOCS, RESULTS, FIGURES, MATH]:
    folder.mkdir(exist_ok=True)

print("Initialized folders:", DOCS, RESULTS, FIGURES, MATH)

# %% [markdown]
# ## Stage metadata

# %%
stage_prefix = "17_17Pi"

stage = {
    "notebook": "17_17Pi_translation_resist",
    "pi_stage": "17Pi",
    "triplet_position": "resist",
    "track": "translation",
    "core_rule": "Preserve measured meaning under interpretation pressure.",
    "template_role": "Generic Pi-stage notebook completing the translation triplet.",
    "translation_boundary": "Do not lock 17Pi to CO2, O2, photons, climate, chemistry, or any domain.",
    "previous_stage": "16_16Pi_translation_extend",
    "next_stage": "18_18Pi_synthesis_expand",
    "cgcs_target": 0.96,
    "template_version": "0.2",
    "outputs": ["docs", "results", "figures", "math"],
    "triplet_map": {
        "15Pi": "expand translation",
        "16Pi": "extend translation",
        "17Pi": "resist translation"
    },
    "translation_resistance_terms": {
        "mapping": "measured quantities remain recoverable",
        "context": "translation context remains explicit",
        "representation": "expression boundary remains preserved",
        "pressure": "public-language interpretation pressure"
    },
}

stage

# %% [markdown]
# ## TPL public-translation resistance gate
#
# The notebook does not translate this yet into CO₂, O₂, photons, climate, chemistry, or any other domain. It only establishes the generic public-translation resistance gate.

# %%
triplet_n = "(Spiral N × 24) − 25"
constraint = "≠ ±9424Pi ≠ 9423Pi"

identity_statement = f"Triplet N = {triplet_n} {constraint}"
print(identity_statement)
print("17Pi resist: measured meaning remains recoverable under interpretation pressure.")

# %% [markdown]
# ## Generic translation resistance components
#
# At 17Pi, translation is not only mapped and extended; measured meaning is preserved under public-language pressure.
#
# Generic translation resistance components:
#
# - consistent representation
# - interpretation pressure
# - preserved mapping
# - preserved context
# - recoverable quantities
# - public-language boundary

# %%
translation_resistance_components = [
    "consistent representation",
    "interpretation pressure",
    "preserved mapping",
    "preserved context",
    "recoverable quantities",
    "public-language boundary",
]

print("Preserving measured meaning under interpretation pressure:")
for item in translation_resistance_components:
    print("-", item)

# %% [markdown]
# ## Generic glossary
#
# | TPL / CGCS term | Generic meaning | Later translations |
# |---|---|---|
# | public translation | measured structure expressed for public context | article, caption, talk note, bridge page |
# | resist | preserve meaning under interpretation pressure | public-language stability |
# | measured meaning | recoverable quantities, context, and representation | mapped variables and terms |
# | interpretation pressure | pressure to replace measurement with persuasive framing | slogan, simplification, ideology |
# | recoverability | ability to map language back to measured structure | inverse mapping |
# | representation boundary | distinction between expression form and measured structure | diagram vs data, prose vs equation |
# | valid construction / VC | translation preserves measured meaning | grounded communication |
# | general-origin story / GOS | system-aware public translation | measurement-preserving language |
# | invalid assignment / IA | persuasive framing replaces measured structure | slogan collapse |
# | zero-origin story / ZOS | claim pretending recoverability is unnecessary | public-language shortcut |
# | CGCS | constraint-gated comprehension score | claim-quality score |

# %%
glossary_md = """# 17 — 17Pi Glossary: Translation Resist

## Core rule

A valid public translation preserves measured meaning under interpretation pressure.

## Translation triplet

- 15Pi: expand measurable rate structure into mapped language
- 16Pi: extend translation across contexts, audiences, and representations
- 17Pi: resist translation collapse by preserving meaning in public language

## Template contract

Every Pi-stage notebook should keep the same output pattern:

- docs/{stage}_glossary.md
- docs/{stage}_notes.md
- docs/{stage}_readme_snippet.md
- results/{stage}_metadata.json
- results/{stage}_claims.json
- results/{stage}_claims.csv
- results/{stage}_manifest.json
- figures/{stage}_*.png
- math/{stage}_*.tex

## Generic terms

| TPL / CGCS term | Generic meaning | Later translations |
|---|---|---|
| public translation | measured structure expressed for public context | article, caption, talk note, bridge page |
| resist | preserve meaning under interpretation pressure | public-language stability |
| measured meaning | recoverable quantities, context, and representation | mapped variables and terms |
| interpretation pressure | pressure to replace measurement with persuasive framing | slogan, simplification, ideology |
| recoverability | ability to map language back to measured structure | inverse mapping |
| representation boundary | distinction between expression form and measured structure | diagram vs data, prose vs equation |
| valid construction / VC | translation preserves measured meaning | grounded communication |
| general-origin story / GOS | system-aware public translation | measurement-preserving language |
| invalid assignment / IA | persuasive framing replaces measured structure | slogan collapse |
| zero-origin story / ZOS | claim pretending recoverability is unnecessary | public-language shortcut |
| CGCS | constraint-gated comprehension score | claim-quality score |

## Translation boundary

17Pi is grammar, not application. Do not lock 17Pi to one domain.

Translate into photons, CO2, O2, climate, chemistry, or public claims later in bridge docs and later notebooks.
"""

(DOCS / "17_17Pi_glossary.md").write_text(glossary_md)
print("Wrote", DOCS / "17_17Pi_glossary.md")

# %% [markdown]
# ## CGCS public-translation scoring
#
# At 17Pi, the score evaluates whether public translation preserves measured meaning under interpretation pressure.
#
# - **0.96:** mapping, context, and representation boundaries remain recoverable.
# - **0.64:** partly grounded but under-specified.
# - **0.33:** persuasive framing replaces measured meaning.
# - **0.00:** incoherent or unsupported assignment.

# %%
claims = [
    {
        "claim": "A valid public translation preserves measured meaning under interpretation pressure.",
        "cgcs": 0.96,
        "classification": "VC/GOS",
        "reason": "Maintains measurement structure through public-language pressure.",
    },
    {
        "claim": "Public interpretation can replace measured meaning when language is persuasive.",
        "cgcs": 0.33,
        "classification": "IA/ZOS",
        "reason": "Confuses persuasive framing with measurement-preserving translation.",
    },
    {
        "claim": "Translation resistance requires preserved mapping, context, and representation boundaries.",
        "cgcs": 0.96,
        "classification": "VC/GOS",
        "reason": "Connects translation extension to public-language stability.",
    },
    {
        "claim": "A translation remains valid even when mapped quantities are no longer recoverable.",
        "cgcs": 0.33,
        "classification": "IA/ZOS",
        "reason": "Removes measurable structure from translation validity.",
    },
]

claims

# %%
(RESULTS / "17_17Pi_metadata.json").write_text(json.dumps(stage, indent=2))
(RESULTS / "17_17Pi_claims.json").write_text(json.dumps(claims, indent=2))

with open(RESULTS / "17_17Pi_claims.csv", "w", newline="") as f:
    writer = csv.DictWriter(f, fieldnames=["claim", "cgcs", "classification", "reason"])
    writer.writeheader()
    writer.writerows(claims)

print("Wrote results JSON/CSV")

# %% [markdown]
# ## Figure 1 — Translation resistance
#
# This figure is intentionally domain-agnostic.
#
# 17Pi completes the translation triplet by preserving measured meaning under interpretation pressure.

# %%
fig, ax = plt.subplots(figsize=(9.4, 3.6))

x = [0, 1, 2]
labels = ["consistent\nrepresentation", "interpretation\npressure", "measured meaning\npreserved"]

ax.scatter(x, [0, 0, 0], s=1000)

for xi, label in zip(x, labels):
    ax.text(xi, -0.42, label, ha="center", va="top", fontsize=12)

ax.annotate("", xy=(0.78, 0), xytext=(0.22, 0), arrowprops=dict(arrowstyle="->", lw=2.5))
ax.annotate("", xy=(1.78, 0), xytext=(1.22, 0), arrowprops=dict(arrowstyle="->", lw=2.5))

ax.text(0, 0.32, "16Pi representation", ha="center", va="bottom", fontsize=10)
ax.text(1, 0.32, "17Pi translation resist", ha="center", va="bottom", fontsize=10)
ax.text(2, 0.32, "mapping + context preserved", ha="center", va="bottom", fontsize=10)

ax.set_title("17Pi translation resist: measured meaning under interpretation pressure")
ax.set_xlim(-0.45, 2.45)
ax.set_ylim(-0.85, 0.65)
ax.axis("off")

fig_path = FIGURES / "17_17Pi_translation_resist.png"
plt.savefig(fig_path, dpi=200, bbox_inches="tight")
plt.show()

print("Saved", fig_path)

# %% [markdown]
# ## Figure 2 — VC/GOS vs IA/ZOS
#
# This figure is the reusable public-translation resistance template: valid construction preserves measured meaning; invalid assignment collapses into interpretation.

# %%
fig, ax = plt.subplots(figsize=(8.5, 4.8))

ax.plot([0.5, 0.5], [0.12, 0.88], linewidth=1.8)

ax.text(0.25, 0.78, "IA / ZOS", ha="center", va="center", fontsize=16, weight="bold")
ax.text(0.25, 0.52, "interpretation\ncollapse", ha="center", va="center", fontsize=12)
ax.text(0.25, 0.27, "mapping lost", ha="center", va="center", fontsize=12)

ax.text(0.75, 0.78, "VC / GOS", ha="center", va="center", fontsize=16, weight="bold")
ax.text(0.75, 0.52, "meaning\npreserved", ha="center", va="center", fontsize=12)
ax.text(0.75, 0.27, "measured\nstructure", ha="center", va="center", fontsize=12)

ax.set_title("17Pi CGCS gate: meaning preserved vs interpretation collapse")
ax.set_xlim(0, 1)
ax.set_ylim(0, 1)
ax.axis("off")

fig_path = FIGURES / "17_17Pi_vc_gos_vs_ia_zos.png"
plt.savefig(fig_path, dpi=200, bbox_inches="tight")
plt.show()

print("Saved", fig_path)

# %% [markdown]
# ## Math output
#
# This TeX output gives each Pi stage a formal layer for papers, 17pi.org, or later combined manuscripts.
#
# 17Pi math stays generic: recoverable measured meaning under interpretation pressure.

# %%
math_tex = r"""\section*{17Pi Translation Resist}

\textbf{Core rule:}
\[
\mathrm{Translation}_{17\Pi}
=
\mathrm{Stable}\left(\mathrm{Translation}_{16\Pi}(K,A,R)\right)
\]

\textbf{Preserved mapping:}
\[
T_{17}(\Delta X,\Delta n,B,C;K,A,R)
=
T_{16}(\Delta X,\Delta n,B,C;K,A,R)
\quad \text{under interpretation pressure}
\]

\textbf{Recoverability condition:}
\[
T^{-1}(\mathcal{L}) \rightarrow \{\Delta X,\Delta n,B,C,K,A,R\}
\]

\textbf{CGCS gate:}
\[
\mathrm{Public\ Translation} \rightarrow
\begin{cases}
\mathrm{meaning\ preserved} & \text{VC/GOS} \\
\mathrm{interpretation\ collapse} & \text{IA/ZOS}
\end{cases}
\]

\textbf{Translation triplet:}
\[
15\Pi:\mathrm{expand}
\quad\rightarrow\quad
16\Pi:\mathrm{extend}
\quad\rightarrow\quad
17\Pi:\mathrm{resist}
\]
"""

(MATH / "17_17Pi_translation.tex").write_text(math_tex)
print("Wrote", MATH / "17_17Pi_translation.tex")

# %% [markdown]
# ## Bridge note stub
#
# This is the generic bridge note. Later docs can translate 17Pi into carbon cycle, photonics, oxygen, climate, chemistry, or public-language analysis.

# %%
notes_md = """# 17 — 17Pi Translation Resist Notes

## Core statement

17Pi preserves measured meaning under interpretation pressure.

## Translation triplet

- 15Pi: expand measurable rate structure into mapped language
- 16Pi: extend translation across contexts, audiences, and representations
- 17Pi: resist translation collapse by preserving meaning in public language

## Translation resistance

17Pi completes the translation triplet.

A valid public translation:
- preserves mapped quantities
- preserves context
- preserves representation boundary
- keeps measured meaning recoverable

An invalid public translation:
- loses mapping
- changes meaning under interpretation pressure
- hides context
- replaces measured structure with persuasive framing

## Figures

### Translation resistance
![17Pi translation resist](../figures/17_17Pi_translation_resist.png)

### CGCS gate (VC/GOS vs IA/ZOS)
![17Pi CGCS gate](../figures/17_17Pi_vc_gos_vs_ia_zos.png)

## Results

### Metadata
- [17_17Pi_metadata.json](../results/17_17Pi_metadata.json)

### Claim scoring
- [17_17Pi_claims.json](../results/17_17Pi_claims.json)
- [17_17Pi_claims.csv](../results/17_17Pi_claims.csv)

### Manifest
- [17_17Pi_manifest.json](../results/17_17Pi_manifest.json)

## Template use

This notebook should be cloned for later Pi stages. Keep the same output pattern:

- docs/*.md for human-readable bridge notes
- results/*.json and results/*.csv for machine-readable claim scoring
- results/*_manifest.json for output inventory
- figures/*.png for site, paper, and seminar visuals
- math/*.tex for formal paper-ready equations

## Translation boundary

17Pi is grammar, not application.

Photons, CO2, O2, carbon cycle, climate claims, and public-language examples should be added in bridge docs or later notebooks, not hard-coded into 17Pi.

## High-CGCS 17Pi framing

A valid public translation preserves measured meaning under interpretation pressure.

## Low-CGCS 17Pi collapse

Public interpretation can replace measured meaning when language is persuasive.
"""

(DOCS / "17_17Pi_notes.md").write_text(notes_md)
print("Wrote", DOCS / "17_17Pi_notes.md")

# %% [markdown]
# ## README snippet
#
# This generated snippet can be copied into `README.md` or adapted for a 17pi.org entry page.

# %%
readme_snippet_md = """## 17 — 17Pi Translation Resist

17Pi preserves measured meaning under interpretation pressure.

**Core rule:** a valid public translation preserves measured meaning under interpretation pressure.

**Translation triplet:** 15Pi expand → 16Pi extend → 17Pi resist.

**Template role:** this notebook completes the translation triplet and preserves the Pi-stage output pattern:

- `docs/` for bridge notes and glossary
- `results/` for CGCS claim scoring and metadata
- `figures/` for reusable visuals
- `math/` for TeX equations

**Public translation stability:** preserved mapping + preserved context + recoverable measured structure.

**Translation boundary:** 17Pi is grammar, not application. Translations into photons, CO2, O2, carbon cycle, climate, chemistry, or public-language claims belong in bridge docs and later notebooks.
"""

(DOCS / "17_17Pi_readme_snippet.md").write_text(readme_snippet_md)
print("Wrote", DOCS / "17_17Pi_readme_snippet.md")

# %% [markdown]
# ## Output manifest
#
# The manifest makes each Pi-stage notebook auditable: it records which files this notebook generated.

# %%
manifest = {
    "notebook": "notebooks/17_17Pi_translation_resist.ipynb",
    "docs": [
        "docs/17_17Pi_glossary.md",
        "docs/17_17Pi_notes.md",
        "docs/17_17Pi_readme_snippet.md",
    ],
    "results": [
        "results/17_17Pi_metadata.json",
        "results/17_17Pi_claims.json",
        "results/17_17Pi_claims.csv",
        "results/17_17Pi_manifest.json",
    ],
    "figures": [
        "figures/17_17Pi_translation_resist.png",
        "figures/17_17Pi_vc_gos_vs_ia_zos.png",
    ],
    "math": [
        "math/17_17Pi_translation.tex",
    ],
}

(RESULTS / "17_17Pi_manifest.json").write_text(json.dumps(manifest, indent=2))
manifest

# %% [markdown]
# ## Validate outputs
#
# This cell checks that the expected generated files exist before export.

# %%
expected_paths = []
for group in ["docs", "results", "figures", "math"]:
    expected_paths.extend(manifest[group])

missing = [path for path in expected_paths if not Path(path).exists()]

if missing:
    raise FileNotFoundError("Missing expected outputs: " + ", ".join(missing))

print("All expected outputs exist.")

# %% [markdown]
# ## Optional export
#
# Run this final cell to zip generated docs, results, figures, and math outputs for download or repo upload.

# %%
EXPORT_NAME = "17_17Pi_translation_resist_export.zip"

with zipfile.ZipFile(EXPORT_NAME, "w", zipfile.ZIP_DEFLATED) as z:
    for folder in [DOCS, RESULTS, FIGURES, MATH]:
        for path in folder.rglob("*"):
            if path.is_file():
                z.write(path, path.as_posix())

print(f"Export ready: {EXPORT_NAME}")
print("Tip: uncomment Colab lines below to download.")

# --- Optional Colab download ---
# Uncomment the lines below when running in Colab
#
# from google.colab import files
# files.download(EXPORT_NAME)
